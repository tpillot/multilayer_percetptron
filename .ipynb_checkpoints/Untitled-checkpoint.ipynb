# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
plt.figure(figsize=(16, 10))

ax = sns.heatmap(df.drop(columns=['M']).corr())

sns.pairplot(df.drop(columns=['842302']), markers="x", height=0.66, aspect=1.7, corner=True, hue='M')

# %%
df.corr().head()
# Out:
#           842302     17.99     10.38     122.8      1001    0.1184    0.2776  \
# 842302  1.000000  0.075166  0.099288  0.073796  0.097390 -0.012343  0.001476
# 17.99   0.075166  1.000000  0.329383  0.997876  0.987344  0.168094  0.505129
# 10.38   0.099288  0.329383  1.000000  0.335918  0.326193 -0.017769  0.252038
# 122.8   0.073796  0.997876  0.335918  1.000000  0.986548  0.204505  0.555676
# 1001    0.097390  0.987344  0.326193  0.986548  1.000000  0.174838  0.497981
#
#           0.3001    0.1471    0.2419  ...     25.38     17.33     184.6  \
# 842302  0.051507  0.045472 -0.021284  ...  0.083457  0.064262  0.081329
# 17.99   0.676557  0.823165  0.144236  ...  0.969964  0.300440  0.966231
# 10.38   0.315248  0.305590  0.080146  ...  0.361964  0.912020  0.369573
# 122.8   0.715662  0.851338  0.179100  ...  0.969675  0.307013  0.971157
# 1001    0.686232  0.824246  0.148219  ...  0.963319  0.290565  0.960440
#
#             2019    0.1622    0.6656    0.7119    0.2654    0.4601    0.1189
# 842302  0.108408  0.010899 -0.001891  0.024177  0.036300 -0.043371 -0.029157
# 17.99   0.941537  0.117392  0.411329  0.525454  0.744025  0.159877  0.003339
# 10.38   0.353434  0.082714  0.290229  0.311122  0.306278  0.116263  0.127177
# 122.8   0.941735  0.148059  0.453304  0.562165  0.770783  0.184458  0.046909
# 1001    0.959952  0.121543  0.388554  0.511392  0.722009  0.139856  0.000382
#
# [5 rows x 31 columns]

# %%
A = np.random.randint(0, 10, size=(3, 3, 2))
B = np.random.randint(0, 10, size=(3, 2, 4))

# %%
Y = np.dot(A,B)
print(np.shape(Y))
# Out:
# (2, 2, 2, 2)
